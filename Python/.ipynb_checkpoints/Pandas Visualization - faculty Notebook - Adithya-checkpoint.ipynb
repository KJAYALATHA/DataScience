# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Matplot Lib
# - Matplotlib is a Python 2D plotting library. Many libraries are built based on it and use its functions in the backend
# - Pyplot is a subpackage of matplotlib that provides a MATLAB-like way of plotting.
# - matplotlib.pyplot is a mostly used package because it is elementary to use, and it generates plots in less time.

# %% [markdown]
# ### 1.1 Line Plot
# A line graph is the most uncomplicated plot that displays the relationship between the one independent and one dependent dataset. In this plot, the points are joined by straight line segments.

# %%
X = np.linspace(1,20,100)
Y = np.exp(X)
plt.plot(X,Y)

# %%
X = np.linspace(1,20,100)
Y = np.exp(X)
plt.plot(X,Y)
plt.show()

# %%
X = np.linspace(1,20,100)
Y = np.exp(X)
plt.plot(X,Y);

# %%
X = np.linspace(1,20,100)
Y = np.exp(X)
plt.plot(X,Y,"r*") #the letter within quotes represents the color and the sy,bol represents the line
plt.show()

# %%
X = np.linspace(1,20,100)
Y = np.exp(X)
plt.plot(X,Y,"b^")
plt.show()

# %%
#There can be multiple line plots in one plot.
#Let us plot three plots together in a single graph. Also, add a plot title.
X = np.linspace(1,20,100)
Y_square = np.square(X)
Y_sqrt = np.sqrt(X)
plt.plot( X,Y_square,'b', X,Y_sqrt,'g')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# ### 1.2 Scatter Plot
#
# - A scatter plot is a set of points plotted on horizontal and vertical axes.
# - The scatter plot can be used to study the correlation between the two variables.
# - One can also detect the extreme data points using a scatter plot.

# %%
sns.load_dataset("Titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#loading the dataset from seaborn
df_tips = sns.load_dataset('tips')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Plot the scatter plot for the variables 'total_bill' and 'tip'
X = df_tips['total_bill']
Y = df_tips['tip']
# set the plot size
plt.scatter(X,Y)
# add the axes labels to the plot
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
#Plot the scatter plot for the variables 'total_bill' and 'tip'
X = df_tips['total_bill']
Y = df_tips['tip']
# set the plot size
plt.figure(figsize=(15,8))
plt.scatter(X,Y)
# add the axes labels to the plot
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %% [markdown]
# ### 1.3 Bar Plot
# - To display categorical data use a  bar plot with bars having lengths proportional to the values that they represent.
# - The comparison between different categories of a categorical variable can be made by studying a bar plot.
# - In the vertical bar plot, the X-axis displays the categorical variable, and Y-axis contains the values corresponding to different categories.

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips['smoker'].value_counts()
#checking the values in the column
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df_tips.tip.value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
df_tips.tip.plot(kind='bar');

# %%
df_tips.smoker.value_counts().plot(kind='bar')
plt.show()

# %%
df_tips.smoker.value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %%
df_tips.smoker.value_counts().plot(kind='bar',rot=0)
plt.show()

# %%
df_tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(15,8))
df_tips.smoker.value_counts().plot(kind='bar', rot = 0, color = 'green')
plt.text(x = 0.96, y = 95, s = 93)
plt.text(x = -0.05, y = 152, s = 151)
plt.title('Bar Plot')
plt.xlabel('Smoker')
plt.ylabel('Count');

# %% [markdown]
# ### 1.4 Pie Plot
# - Pie plot is a graphical representation of univariate data.
# - It is a circular graph divided into slices displaying the numerical proportion.
# - For the categorical variable, each slice of the pie plot corresponds to each of the categories.

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
plt.pie(df_tips.day.value_counts());

# %%
plt.pie(df_tips.day.value_counts(),labels = ['Sat', 'Sun','Thur','Fri']);

# %%
plt.pie(df_tips.day.value_counts(),labels = ['Sat', 'Sun','Thur','Fri'],autopct="%.0f%%");
#f represents the format similar to like in label

# %%
plt.pie(df_tips.day.value_counts(),labels = ['Sat', 'Sun','Thur','Fri'],autopct="%.1f%%",radius=1.5);

# %%
plt.pie(df_tips.day.value_counts(), autopct = '%.1f%%', radius = 1.2, labels = ['Sat', 'Sun','Thur','Fri'],
        explode = [0,0.2,0,0]);

# %%
# plot the occurrence of different days in the dataset

# 'autopct' displays the percentage upto 1 decimal place
# 'radius' sets the radius of the pie plot
# 'labels' are the labels given to each section 
# 'explode' specifies the radius with which to offset each section

# %% [markdown]
# ### 1.5 Histogram
# - A histogram is used to display the distribution and spread of the continuous variable.
# - One axis represents the range of variable, and the other axis shows the frequency of the data points.
# - In a histogram, there are no gaps between the bars.

# %%
plt.hist(df_tips['tip'], bins= 5)
plt.title('Distribution of tip amount')
plt.xlabel('tip')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df_tips['tip'], bins= 3)
plt.title('Distribution of tip amount')
plt.xlabel('tip')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 1.6 Box Plot
# - Boxplot is a way to visualize the five-number summary of the variable.
# - The five-number summary includes the numerical quantities like minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
# - It gives information about the outliers in the data.
# - Detecting and removing outliers is one of the essential steps in exploratory data analysis.
# - Boxplots also tells about the distribution of the data.

# %%
plt.boxplot(df_tips['total_bill']);

# %% [markdown]
# - The above boxplot clearly shows the presence of outliers above the horizontal line.
# - We can add an arrow to showcase the outliers. Also, the median (Q2) is represented by the orange line, which is nearer to Q1 than Q3, indicating that the total bill is positively skewed.

# %% [markdown]
# ## 2. Plots using Seaborn
#
# - Seaborn is a Python visualization library based on matplotlib.
# - The library provides a high-level interface for plotting statistical graphics.
# - As the library uses matplotlib in the backend, we can use the functions in matplotlib along with functions in seaborn.
# - Various functions in the seaborn library allow us to plot complex and advance statistical plots such as linear/higher-order regression, univariate/multivariate distribution, violin, swarm, strip plots, correlations.

# %% [markdown]
# ### 2.1 Strip Plot
#
# The strip plot resembles a scatterplot when one variable is numrical. This plot can help study the underlying distribution of the data.

# %%
sns.stripplot(data = df_tips)

# display the plot
plt.show()

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.stripplot(y = 'tip', x = 'time', data = df_tips);

# %% [markdown]
# We see that the tip amount is more at dinner time than at lunchtime. Nevertheless, the above plot is unable to display the spread of the data. We can plot the points with spread using the 'jitter' parameter in the strip plot function.

# %%
# jitter to spread the points
sns.stripplot(y = 'tip', x = 'time', data = df_tips, jitter = True);

# %% [markdown]
# The plot shows most of the observations the tip amount is in the range 1 to 4 irrespective of time.

# %% [markdown]
# ### 2.2 Swarm Plot
# - The swarm plot is similar to the strip plot, but it avoids the overlapping of the points, giving a better representation of the distribution of the data.

# %%
sns.swarmplot(y = 'tip', x = 'time', data = df_tips);

# %%
sns.swarmplot(y = 'tip', x = 'time', data = df_tips, hue = 'day');

# %% [markdown]
# ### 2.3 Distribution Plot
# A seaborn provides a distplot() function to visualize a distribution of the univariate variable. This function uses matplotlib to plot a histogram and fit a kernel density estimate (KDE).

# %%
# plot a distribution plot
sns.distplot(df_tips['total_bill'])

# display the plot
plt.show()

# %%
# plot a distribution plot
sns.displot(df_tips['total_bill'])

# display the plot
plt.show()

# %%
# plot a distribution plot
sns.displot(df_tips['total_bill'],kde=True)

# display the plot
plt.show()

# %% [markdown]
# We can interpret from the above plot that the total bill amount is between 10 to 20 for a large number of observations. The distribution plot can be used to visualize the total bill for different times of the day.

# %% [markdown]
# ### 2.4 Count Plot
# Count plot shows the count of observations in each category of a categorical variable. We can add another variable using a parameter 'hue'.

# %%
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot(data = df_tips, x ="time",y=df_tips.time.value_counts());
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11172/4235463567.py in <module>
# ----> 1 sns.countplot(data = df_tips, x ="time",y=df_tips.time.value_counts());
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594         y = x
#    3595     elif x is not None and y is not None:
# -> 3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
#    3598     plotter = _CountPlotter(
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
sns.countplot(data = df_tips, x = 'day',hue="time");

# %%
sns.countplot(data = df_tips, x = 'day',y='sex');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15096/2027700497.py in <module>
# ----> 1 sns.countplot(data = df_tips, x = 'day',y='sex');
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594         y = x
#    3595     elif x is not None and y is not None:
# -> 3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
#    3598     plotter = _CountPlotter(
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
sns.countplot(data = df_tips, x = 'day', hue = 'time');

# %% [markdown]
# ### 2.5 Regression Plot
# Regression plot is a plot which gives the relationship with two quantitative variables

# %% [markdown]
# The line regression plot in this library plots the data and the fitted regression model.

# %%
sns.regplot(x = "total_bill", y = "tip", data = df_tips)

# display the plot
plt.show()

# %% [markdown]
# The above plot is a scatter plot of the tip against the total bill. We may say as the bill amount increases the tip amount also increases, that is, there is an increasing  trend.

# %% [markdown]
# ### 2.6 Joint plot
# A joint plot is a bivariate plot along with the distribution plot along the margins.

# %%
# plot a joint plot
# data specifies the DataFrame to be used
sns.JointGrid(x = "total_bill", y = "tip", data = df_tips).plot(sns.scatterplot, sns.kdeplot)

# display the plot
plt.show()

# %% [markdown]
# We see there is a nearly linear relationship between the total bill and the tip. Along the margins, we see the kernel density plot for the variables.
#
# It is possible to plot the distribution plot or even histogram. Also, the scatter plot can be replaced by the regression plot.

# %% [markdown]
# ### 2.7 Violin Plot
# The violin plot is similar to a box plot that features a kernel density estimation of the underlying distribution. The plot shows the distribution of numerical variables across categories of one (or more) categorical variables such that those distributions can be compared.

# %%
# violin plot
# data specifies the DataFrame to be used
sns.violinplot(y = 'total_bill', x = 'day', data = df_tips)

# display the plot
plt.show()

# %% [markdown]
# The above violin plot shows that the total bill distribution is nearly the same for different days. We can add another categorical variable 'sex' to the above plot to get a better insight on the bill amount distribution based on days as well as gender.

# %%
plt.figure(figsize = (15,8))
sns.violinplot(y = 'total_bill', x = 'day', data = df_tips, hue = 'sex', split = True)

# display the plot
plt.show()

# %% [markdown]
# ### 2.8 Pair Plot
# The pair plot gives a pairwise distribution of variables in the dataset. The pairplot() function creates a matrix such that each grid shows the relationship between a pair of variables. On the diagonal axes, a plot shows the univariate distribution of each variable.

# %%
plt.figure(figsize = (15,8))

# plot a pair plot
sns.pairplot(df_tips)

# display the plot
plt.show()

# %% [markdown]
# - The above plot shows the relationship between all the numerical variables.
# - 'total_bill' and 'tip' has a positive linear relationship with each other.
# - Also, 'total_bill' and 'tip' are positively skewed.
# - The 'size' has a significant impact on the 'total_bill', as the minimum bill amount is increasing with an increasing number of customers (size).

# %% [markdown]
# ### 2.9 Heatmap
# Heatmap is a  graphical representation of two-dimensional data. It represents the individual values that are contained in a matrix are represented as colours. <br><br>
#                        Generally, the heatmap is used to the correlation matrix among numeric variables of a dataset. Each square in the heatmap shows the correlation between the two variables on each axis.

# %%
corr_matrix =df_tips.corr()

# display the correlation matrix
corr_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %%
sns.heatmap(df_tips.corr(), annot = True)

# display the plot
plt.show()
